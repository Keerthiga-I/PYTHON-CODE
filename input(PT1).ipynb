# %% [markdown]
# <a href="https://colab.research.google.com/github/Keerthiga-I/PYTHON-CODE/blob/PYTHON-LEVELS/input(PT1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# basic method of input output
# input N
n = int(input())
# Out:
# 5

# %%
# input the array
arr = [int(x) for x in input().split()]
print(arr)
# Out:
# 10
# [10]

# %%
arr=input().split()
print(arr)
for x in arr:
    print(int(x))
# Out:
# 20
# ['20']
# 20

# %%
# Input -> 10 20 monkey
a, b, c = input().split(' ')
print(a, b, c)
# Out:
# 10 20 30
# 10 20 30

# %%
arr = map(int,input().split())
print(arr)
print(list(arr))
print(tuple(arr))
# Out:
# 20 30
# ...
# [20, 30]
# ()

# %%
def square(x):
  return x*x

num=[12,34,56]
arr = map(square,num)

print(list(arr))
# Out:
# [144, 1156, 3136]

# %%
# Input with map -> 10 20
a, b = map(int, input().split(' '))
print(a, b)
# Input with map -> 10, 20
a, b = map(int,input().split(','))
print(a, b)
# Out:
# 10 30
# 10 30
# 10,30
# 10 30

# %%
# taking a variable number of input in string and convert them to a list
l = list(input().split())
print (l)
# Out:
# 5
# ['5']

# %%
l=set(input().split())
arr=map(int,l)
print(arr)
print(l)
# Out:
# 25
# ...
# {'25'}

# %%
#Mathematics
#Sum Formulas -> 1 + 2 + 3 ... n = n(n+1)/2
#Sum Formulas -> 1^k + 2^k + 3^k ... n^k = n(n+1)(2n+1)/6
#AP -> a + .. + b = n(a+b)/2
#GP -> a + ak + ak^2 + .. + b = (bk -a) / (k - 1)
ap = [3, 7, 11, 15]
print(4*(3+15)/2)
# Out:
# 36.0

# %%
gp = [3, 6, 12, 24] # k is 2 here  #3*2^0 3*2^1 3*2^2 3*2^3
print((24*2 - 3)/(2-1))
# Out:
# 45.0

# %%
# Set
x = set([2, 4, 7])
a = set([1, 2, 5])
b = set([2, 4])
print(x)
print(a.intersection(b)) #&
print(a.union(b))        #|
print(a.difference(b))   #-
print(a.symmetric_difference(b)) #^
# Out:
# {2, 4, 7}
# {2}
# {1, 2, 4, 5}
# {1, 5}
# {1, 4, 5}

# %%
# Logarithms
# logk(a, b) = logk(a) + logk(b)
# logk(x^n) = n * logk(x)
# logk(a/b) = logk(a) - logk(b)
# logu(x) = logk(x) / logk(u)
import math
print(math.log(32, 2))
# Out:
# 5.0

# %%
# Functions
print(3/2)
print(min([1, 2, 3]))
print(max([1, 2, 3]))
print(math.factorial(10))
# Out:
# 1.5
# 1
# 3
# 3628800

# %%
# C or Java type Loops
my_items = ['a','b','c']
i=0
while i<len(my_items):
  print(my_items[i])
  i+=1
# Out:
# a
# b
# c

# %%
for i in range(len(my_items)):
    print(my_items[i])
# Out:
# a
# b
# c

# %%
# for each python loop
for item in my_items:
    print(item)
# Out:
# a
# b
# c

# %%
for i, item in enumerate(my_items):
  print(f'index->{i}: value->{item}')
# Out:
# index->0: value->a
# index->1: value->b
# index->2: value->c

# %%
name='xxxx'
age=12
print(f'I am {name} My age is{age}')
# Out:
# I am xxxx My age is12

# %%
# pythonic looping through dictionary
emails = {
    'Bob' : 'bob@example.com',
    'Alice' : 'alice@example.com',
}

for name, email in emails.items():
    print(f'{name} -> {email}')
# Out:
# Bob -> bob@example.com
# Alice -> alice@example.com

# %%
# values = [expression for item in collection]
#    is same as
# values = []
# for item in collection:
#     values.append(expression)
squares = []

# %%
for x in range(10):
    squares.append(x*x)
squares
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
squares=[x*x for x in range(10)]
squares
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
even_squares = [x*x for x in range(10) if x % 2 == 0]
even_squares
# Out:
# [0, 4, 16, 36, 64]

# %%
even_squares=[]
for x in range(10):
    if x%2==0:
        even_squares.append(x*x)
even_squares
# Out:
# [0, 4, 16, 36, 64]

# %%
# sets are unordered
{x*x for x in range(-9,10)}
# Out:
# {0, 1, 4, 9, 16, 25, 36, 49, 64, 81}

# %%
# dictionary
{x: x*x for x in range(5)}
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16}
