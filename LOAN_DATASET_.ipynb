# %% [markdown]
# <a href="https://colab.research.google.com/github/Keerthiga-I/PYTHON-CODE/blob/PYTHON-LEVELS/LOAN_DATASET_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **IMPORT LIBRARIS**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **DATA PREPROCESSING**

# %%
df = pd.read_csv('/loan_dataset.csv')
df.head()
# Out:
#    Unnamed: 0     ID  Pin-code  age  Fam members       Education  \
# 0           0  10001    110001   23          4.0  Under Graduate
# 1           1  10002    110014   43          3.0  Under Graduate
# 2           2  10003    110014   37          1.0  Under Graduate
# 3           3  10004    110003   33          1.0        Graduate
# 4           4  10005    110004   33          4.0        Graduate
#
#    T.Experience  Income  Mortgage Fixed Deposit Demat Net Banking Loan
# 0           1.0  392000         0            no   yes          no   no
# 1          19.0  272000         0            no   yes          no   no
# 2          15.0   88000         0            no    no          no   no
# 3           9.0  800000         0            no    no          no   no
# 4           8.0  360000         0            no    no          no   no

# %%
df.tail()
# Out:
#       Unnamed: 0        ID  Pin-code  age  Fam members       Education  \
# 4995        4995  10004996    110014   27          1.0   Post Graduate
# 4996        4996  10004997    110004   28          4.0  Under Graduate
# 4997        4997  10004998    110014   61          2.0   Post Graduate
# 4998        4998  10004999    110003   63          3.0        Graduate
# 4999        4999  10005000    110001   26          3.0  Under Graduate
#
#       T.Experience  Income  Mortgage Fixed Deposit Demat Net Banking Loan
# 4995           3.0  320000         0            no    no         yes   no
# 4996           4.0  120000    680000            no    no         yes   no
# 4997          39.0  192000         0            no    no          no   no
# 4998          40.0  392000         0            no    no         yes   no
# 4999           4.0  664000         0            no    no         yes   no

# %%
df.shape
# Out:
# (5000, 13)

# %%
df.columns.to_list()
# Out:
# ['Unnamed: 0',
#  'ID',
#  'Pin-code',
#  'age',
#  'Fam members',
#  'Education',
#  'T.Experience',
#  'Income',
#  'Mortgage',
#  'Fixed Deposit',
#  'Demat',
#  'Net Banking',
#  'Loan']

# %%
df.describe()
# Out:
#         Unnamed: 0            ID       Pin-code          age  Fam members  \
# count  5000.000000  5.000000e+03    5000.000000  5000.000000  5000.000000
# mean   2499.500000  8.186318e+06  110006.557800    43.338400     2.396400
# std    1443.520003  3.638026e+06       4.998725    11.463166     1.147663
# min       0.000000  1.000100e+04  110001.000000    21.000000     1.000000
# 25%    1249.750000  1.000125e+07  110003.000000    33.000000     1.000000
# 50%    2499.500000  1.000250e+07  110004.000000    43.000000     2.000000
# 75%    3749.250000  1.000375e+07  110011.000000    53.000000     3.000000
# max    4999.000000  1.000500e+07  110014.000000    65.000000     4.000000
#
#        T.Experience        Income      Mortgage
# count   5000.000000  5.000000e+03  5.000000e+03
# mean      20.104600  5.901936e+05  4.519904e+05
# std       11.467954  3.682698e+05  8.137104e+05
# min       -3.000000  6.400000e+04  0.000000e+00
# 25%       10.000000  3.120000e+05  0.000000e+00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     5000 non-null   int64
#  1   ID             5000 non-null   int64
#  2   Pin-code       5000 non-null   int64
#  3   age            5000 non-null   int64
#  4   Fam members    5000 non-null   float64
#  5   Education      5000 non-null   object
#  6   T.Experience   5000 non-null   float64
#  7   Income         5000 non-null   int64
#  8   Mortgage       5000 non-null   int64
#  9   Fixed Deposit  5000 non-null   object
#  10  Demat          5000 non-null   object
#  11  Net Banking    5000 non-null   object
#  12  Loan           5000 non-null   object
# dtypes: float64(2), int64(6), object(5)
# memory usage: 507.9+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique()
# Out:
# Unnamed: 0       5000
# ID               5000
# Pin-code            5
# age                45
# Fam members         4
# Education           3
# T.Experience       47
# Income            162
# Mortgage          347
# Fixed Deposit       2
# Demat               2
# Net Banking         2
# Loan                2
# dtype: int64

# %%
df['Education'].unique()
# Out:
# array(['Under Graduate', 'Graduate', 'Post Graduate'], dtype=object)

# %%
df.isna().sum()
# Out:
# Unnamed: 0       0
# ID               0
# Pin-code         0
# age              0
# Fam members      0
# Education        0
# T.Experience     0
# Income           0
# Mortgage         0
# Fixed Deposit    0
# Demat            0
# Net Banking      0
# Loan             0
# dtype: int64

# %%
df
# Out:
#       Unnamed: 0        ID  Pin-code  age  Fam members       Education  \
# 0              0     10001    110001   23          4.0  Under Graduate
# 1              1     10002    110014   43          3.0  Under Graduate
# 2              2     10003    110014   37          1.0  Under Graduate
# 3              3     10004    110003   33          1.0        Graduate
# 4              4     10005    110004   33          4.0        Graduate
# ...          ...       ...       ...  ...          ...             ...
# 4995        4995  10004996    110014   27          1.0   Post Graduate
# 4996        4996  10004997    110004   28          4.0  Under Graduate
# 4997        4997  10004998    110014   61          2.0   Post Graduate
# 4998        4998  10004999    110003   63          3.0        Graduate
# 4999        4999  10005000    110001   26          3.0  Under Graduate
#
#       T.Experience  Income  Mortgage Fixed Deposit Demat Net Banking Loan
# ...

# %%
df1=df.drop(columns=["Unnamed: 0","ID","Pin-code"])
df1
# Out:
#       age  Fam members       Education  T.Experience  Income  Mortgage  \
# 0      23          4.0  Under Graduate           1.0  392000         0
# 1      43          3.0  Under Graduate          19.0  272000         0
# 2      37          1.0  Under Graduate          15.0   88000         0
# 3      33          1.0        Graduate           9.0  800000         0
# 4      33          4.0        Graduate           8.0  360000         0
# ...   ...          ...             ...           ...     ...       ...
# 4995   27          1.0   Post Graduate           3.0  320000         0
# 4996   28          4.0  Under Graduate           4.0  120000    680000
# 4997   61          2.0   Post Graduate          39.0  192000         0
# 4998   63          3.0        Graduate          40.0  392000         0
# 4999   26          3.0  Under Graduate           4.0  664000         0
#
#      Fixed Deposit Demat Net Banking Loan
# 0               no   yes          no   no
# ...

# %%
binary_cols = ["Fixed Deposit", "Demat", "Net Banking", "Loan"]
df[binary_cols] = df[binary_cols].applymap(lambda x: 1 if x.strip().lower() == "yes" else 0)
# Out:
# <ipython-input-32-015eb4101c80>:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df[binary_cols] = df[binary_cols].applymap(lambda x: 1 if x.strip().lower() == "yes" else 0)

# %%
df[binary_cols]
# Out:
#       Fixed Deposit  Demat  Net Banking  Loan
# 0                 0      1            0     0
# 1                 0      1            0     0
# 2                 0      0            0     0
# 3                 0      0            0     0
# 4                 0      0            0     0
# ...             ...    ...          ...   ...
# 4995              0      0            1     0
# 4996              0      0            1     0
# 4997              0      0            0     0
# 4998              0      0            1     0
# 4999              0      0            1     0
#
# [5000 rows x 4 columns]

# %% [markdown]
# #**RELATIONSHIP ANALYSIS**

# %%
numeric_df = df.select_dtypes(include=['float64', 'int64'])
corr = numeric_df.corr()
plt.figure(figsize=(20, 8))
sns.heatmap(corr, annot=True)
plt.title("Correlation Heatmap of Numerical Features")
plt.show()

# %%
sns.pairplot(df)

# %%
sns.relplot(x='Income', y='age',hue='Loan', data=df)

# %%
sns.relplot(x='Education', y='Income',hue='Loan', data=df)

# %%
sns.displot(df['Income'])

# %%
sns.displot(df['T.Experience'],bins=5)

# %%
sns.catplot(x='Income',kind='box',data=df)

# %%
loan_counts = df['Loan'].value_counts()
plt.figure(figsize=(6, 6))
plt.pie(loan_counts, labels=['Did Not Loan', 'Loan'])
plt.title('Loan Proportion')
plt.axis('equal')
plt.show()

# %%
# !pip install nbconvert

# %% [markdown]
# #**MACHINE LEARING**

# %%
# Step 1: Import necessary libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import classification_report, accuracy_score

# Step 2: Load the dataset
df = pd.read_csv('/loan_dataset.csv')

# Step 3: Drop unnecessary columns
df = df.drop(columns=["Unnamed: 0", "ID", "Pin-code"])

# Step 4: Convert 'yes'/'no' to 1/0 in binary columns
binary_cols = ["Fixed Deposit", "Demat", "Net Banking", "Loan"]
for col in binary_cols:
    df[col] = df[col].str.strip().str.lower().map({'yes': 1, 'no': 0})

# Step 5: Encode 'Education' column
le = LabelEncoder()
df['Education'] = le.fit_transform(df['Education'])

# Step 6: Define input (X) and target (y)
X = df.drop("Loan", axis=1)
y = df["Loan"]

# Step 7: Normalize input features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Step 8: Split the data (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42, stratify=y)

# Step 9: Train the model
svm_model = SVC(kernel='rbf', C=1, gamma='scale')
svm_model.fit(X_train, y_train)

# Step 10: Predict and evaluate
y_pred = svm_model.predict(X_test)
print(" SVM Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
#  SVM Accuracy: 0.978
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       904
#            1       0.95      0.81      0.88        96
#
#     accuracy                           0.98      1000
#    macro avg       0.97      0.90      0.93      1000
# weighted avg       0.98      0.98      0.98      1000
