# %% [markdown]
# DATA TYPES

# %%
a=10
print(a)
print(type(a))
# Out:
# 10
# <class 'int'>

# %%
b=24
print(b)
print(type(b))
# Out:
# 24
# <class 'int'>

# %%
c='Hi all.Welcome to the session'
print(c)
print(type(c))
d=25.5
print(d)
print(type(d))
# Out:
# Hi all.Welcome to the session
# <class 'str'>
# 25.5
# <class 'float'>

# %%
import seaborn as sns
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
irisdata = sns.load_dataset('iris')
irisdata.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
type('b')
# Out:
# str

# %%
a=10
b=25
c=a+b
print(c)
# Out:
# 35

# %%
print('My name is Anusha')
print("My name is BanuSri")
print('c')
print(c)
print('')
# Out:
# My name is Anusha
# My name is BanuSri
# c
# 35

# %%
a=100
b=300
c=a+b
print('c=',c)
print("Addition of a=",a,"and b=",b,"is c=",c)
# Out:
# c= 400
# Addition of a= 100 and b= 300 is c= 400

# %%
a = 567890431244456523626763871
print(a)
c1=2+3j
c2=4-6j
c3=c1+c2
print(c3)
type(c3)
# Out:
# 567890431244456523626763871
# (6-3j)
# complex

# %%
type('Hello World')
# Out:
# str

# %%
type("3.00")
# Out:
# str

# %%
a=3,00,00
print(a)
# Out:
# (3, 0, 0)

# %%
str1=' hello world'
str2=' how are you'
z=str1 + str2
print(z)
print(str2 * 4)
# Out:
#  hello world how are you
#  how are you how are you how are you how are you

# %%
s="Welcome chennai"
print(s)
print(s[0])
print(s[5])
print(s[9])
print(s[-1])
print(s[-7])
print(s[8:16])
print(s[3:])
print(s[:3])
print(s[-5:-2])
print(s)
print(s[::-1])
# Out:
# Welcome chennai
# W
# m
# h
# i
# c
# chennai
# come chennai
# Wel
# enn
# Welcome chennai
# iannehc emocleW

# %%
str3= 'keerthigairisan  '
str3* 5
# Out:
# 'keerthigairisan  keerthigairisan  keerthigairisan  keerthigairisan  keerthigairisan  '

# %%
print(2+3-1)
print(1+1**5-1)
print(1+1**(5-2))
print(2+3/2)
print(3-5**(6-4)/2)
# Out:
# 4
# 1
# 2
# 3.5
# -9.5
