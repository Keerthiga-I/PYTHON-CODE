# %% [markdown]
# <a href="https://colab.research.google.com/github/Keerthiga-I/PYTHON-CODE/blob/PYTHON-LEVELS/pandas_lib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = [{'A':1,'B':2*i} for i in range(3)]
data
# Out:
# [{'A': 1, 'B': 0}, {'A': 1, 'B': 2}, {'A': 1, 'B': 4}]

# %%
df = pd.DataFrame(data)
df
# Out:
#    A  B
# 0  1  0
# 1  1  2
# 2  1  4

# %%
df = pd.DataFrame(data,index=['X','Y','Z'])
df
# Out:
#    A  B
# X  1  0
# Y  1  2
# Z  1  4

# %%
df.columns
# Out:
# Index(['A', 'B'], dtype='object')

# %%
df.columns = ['A','B']
df
# Out:
#    A  B
# 0  1  0
# 1  1  2
# 2  1  4

# %%
df.index = ['m','n','o']
df
# Out:
#    A  B
# m  1  0
# n  1  2
# o  1  4
